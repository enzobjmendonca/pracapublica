# %%
from src.clients.camara_client import CamaraClient
import pandas as pd
camara_client = CamaraClient()

# %% [markdown]
# List all members of the Chamber of Deputies

# %%
deputados = camara_client.get_deputados()
deputados_df = pd.DataFrame(deputados)
deputados_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
#          id                                                uri  \
# 0    204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1    220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3    204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# ...

# %% [markdown]
# Get members of the Chamber of Deputies in a previous legislature

# %%
deputados_56_legislature = camara_client.get_deputados(idLegislatura = 56)
deputados_56_legislature_df = pd.DataFrame(deputados_56_legislature)
deputados_56_legislature_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados
# ...

# %% [markdown]
# Infomation about the deputies

# %%
camara_client.get_deputado(deputado_id = 204379)
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379
# {'dados': {'id': 204379,
#   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#   'nomeCivil': 'ACÁCIO DA SILVA FAVACHO NETO',
#   'ultimoStatus': {'id': 204379,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#    'nome': 'Acácio Favacho',
#    'siglaPartido': 'MDB',
#    'uriPartido': None,
#    'siglaUf': 'AP',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204379.jpg',
#    'email': None,
#    'data': '2023-02-01',
#    'nomeEleitoral': 'Acácio Favacho',
#    'gabinete': {'nome': '414',
#     'predio': '4',
#     'sala': '414',
#     'andar': '4',
#     'telefone': '3215-5414',
#     'email': 'dep.acaciofavacho@camara.leg.br'},
#    'situacao': 'Exercício',
#    'condicaoEleitoral': 'Titular',
#    'descricaoStatus': None},
#   'cpf': '74287028287',
#   'sexo': 'M',
# ...

# %%
despesas = camara_client.get_deputado_despesas(deputado_id = 204379, ano = 2025)
despesas_df = pd.DataFrame(despesas)
despesas_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/despesas
#       ano  mes                                        tipoDespesa  \
# 0    2025    1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1    2025    2  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2    2025    3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3    2025    4  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4    2025    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# ..    ...  ...                                                ...
# 240  2025    7                            PASSAGEM AÉREA - SIGEPA
# 241  2025    7                            PASSAGEM AÉREA - SIGEPA
# ...

# %%
discursos = camara_client.get_deputado_discursos(deputado_id = 204379, dataInicio = '2025-01-01', dataFim = '2025-12-31')
discursos_df = pd.DataFrame(discursos)
discursos_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/discursos
#       dataHoraInicio dataHoraFim uriEvento  \
# 0   2025-09-02T13:55        None
# 1   2025-07-16T10:00        None
# 2   2025-07-02T13:55        None
# 3   2025-06-16T18:00        None
# 4   2025-06-10T13:55        None
# 5   2025-05-28T13:55        None
# 6   2025-04-29T13:55        None
# 7   2025-04-02T10:32        None
# 8   2025-04-01T13:55        None
# 9   2025-03-12T13:55        None
# 10  2025-02-26T17:20        None
# 11  2025-02-19T13:55        None
# 12  2025-02-12T13:55        None
# 13  2025-02-11T13:55        None
# 14  2025-02-05T13:55        None
# 15  2025-02-04T13:55        None
#
#                                            faseEvento          tipoDiscurso  \
# 0   {'titulo': 'Encerramento', 'dataHoraInicio': N...  DISCURSO ENCAMINHADO
# 1   {'titulo': 'Encerramento', 'dataHoraInicio': N...  DISCURSO ENCAMINHADO
# ...

# %%
discursos
# Out:
# [{'dataHoraInicio': '2025-09-02T13:55',
#   'dataHoraFim': None,
#   'uriEvento': '',
#   'faseEvento': {'titulo': 'Encerramento',
#    'dataHoraInicio': None,
#    'dataHoraFim': None},
#   'tipoDiscurso': 'DISCURSO ENCAMINHADO',
#   'urlTexto': 'https://imagem.camara.gov.br/dc_20b.asp?largura=&altura=&tipoForm=diarios&selCodColecaoCsv=D&Datain=3%2F9%2F2025&txPagina=239&txSuplemento=&enviar=Pesquisar',
#   'urlAudio': None,
#   'urlVideo': None,
#   'keywords': 'Amapá (AP),Porto de Santana,Comércio internacional,Importação,Exportação,China,Logística,Desenvolvimento regional',
# ...

# %%
eventos = camara_client.get_deputado_eventos(deputado_id = 204379, dataInicio = '2025-01-01', dataFim = '2025-12-31')
eventos_df = pd.DataFrame(eventos)
eventos_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/eventos
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/eventos
#         id                                                uri  \
# 0    75379  https://dadosabertos.camara.leg.br/api/v2/even...
# 1    75386  https://dadosabertos.camara.leg.br/api/v2/even...
# 2    75389  https://dadosabertos.camara.leg.br/api/v2/even...
# 3    75392  https://dadosabertos.camara.leg.br/api/v2/even...
# 4    75395  https://dadosabertos.camara.leg.br/api/v2/even...
# ..     ...                                                ...
# 103  79236  https://dadosabertos.camara.leg.br/api/v2/even...
# 104  79121  https://dadosabertos.camara.leg.br/api/v2/even...
# 105  79194  https://dadosabertos.camara.leg.br/api/v2/even...
# 106  77637  https://dadosabertos.camara.leg.br/api/v2/even...
# ...

# %%
frentes = camara_client.get_deputado_frentes(deputado_id = 204379)
frentes_df = pd.DataFrame(frentes)
frentes_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/204379/frentes
#         id                                                uri  \
# 0    55686  https://dadosabertos.camara.leg.br/api/v2/fren...
# 1    55595  https://dadosabertos.camara.leg.br/api/v2/fren...
# 2    55662  https://dadosabertos.camara.leg.br/api/v2/fren...
# 3    55671  https://dadosabertos.camara.leg.br/api/v2/fren...
# 4    55649  https://dadosabertos.camara.leg.br/api/v2/fren...
# ..     ...                                                ...
# 194  53975  https://dadosabertos.camara.leg.br/api/v2/fren...
# 195  53929  https://dadosabertos.camara.leg.br/api/v2/fren...
# 196  53909  https://dadosabertos.camara.leg.br/api/v2/fren...
# 197  53901  https://dadosabertos.camara.leg.br/api/v2/fren...
# 198  53889  https://dadosabertos.camara.leg.br/api/v2/fren...
#
#                                                 titulo  idLegislatura
# ...

# %%
ocupacoes = camara_client.get_deputado_ocupacoes(deputado_id = 160592)
ocupacoes_df = pd.DataFrame(ocupacoes)
ocupacoes_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/160592/ocupacoes
#                  titulo                                           entidade  \
# 0        Chefe Regional  Secretaria de Estado do Trabalho, Emprego e Pr...
# 1  Secretário Municipal                               Indústria e Comércio
# 2            Empresário                               Microsys Informática
#
#   entidadeUF entidadePais  anoInicio  anoFim
# 0         PR       BRASIL       2003    2004
# 1         PR       BRASIL       2001    2002
# 2         PR       BRASIL       1998    2003

# %%
orgaos = camara_client.get_deputado_orgaos(deputado_id = 160592)
orgaos_df = pd.DataFrame(orgaos)
orgaos_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/160592/orgaos
#    idOrgao                                           uriOrgao siglaOrgao  \
# 0     5973  https://dadosabertos.camara.leg.br/api/v2/orga...   MERCOSUL
# 1     2009  https://dadosabertos.camara.leg.br/api/v2/orga...         CE
# 2     2014  https://dadosabertos.camara.leg.br/api/v2/orga...     CSAUDE
# 3     2018  https://dadosabertos.camara.leg.br/api/v2/orga...      CREDN
# 4     2009  https://dadosabertos.camara.leg.br/api/v2/orga...         CE
# 5   539777  https://dadosabertos.camara.leg.br/api/v2/orga...   PL261424
# 6   539776  https://dadosabertos.camara.leg.br/api/v2/orga...   PL233823
# 7   539731  https://dadosabertos.camara.leg.br/api/v2/orga...   PEC01421
#
#                                            nomeOrgao  \
# 0  Representação Brasileira no Parlamento do Merc...
# 1                               Comissão de Educação
# ...

# %%
profissoes = camara_client.get_deputado_profissoes(deputado_id = 160592)
profissoes_df = pd.DataFrame(profissoes)
profissoes_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/160592/profissoes
#            dataHora  codTipoProfissao      titulo
# 0  2018-08-14T16:36               182  Empresário

# %%
historico = camara_client.get_deputado_historico(deputado_id = 160592, dataInicio = '2020-01-01', dataFim = '2025-12-31')
historico_df = pd.DataFrame(historico)
historico_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/160592/historico
#        id                                                uri         nome  \
# 0  160592  https://dadosabertos.camara.leg.br/api/v2/depu...  Zeca Dirceu
# 1  160592  https://dadosabertos.camara.leg.br/api/v2/depu...  Zeca Dirceu
# 2  160592  https://dadosabertos.camara.leg.br/api/v2/depu...  Zeca Dirceu
#
#   nomeEleitoral siglaPartido  \
# 0   Zeca Dirceu           PT
# 1   Zeca Dirceu           PT
# 2   Zeca Dirceu           PT
#
#                                           uriPartido siglaUf  idLegislatura  \
# 0  https://dadosabertos.camara.leg.br/api/v2/part...      PR             56
# 1  https://dadosabertos.camara.leg.br/api/v2/part...      PR             57
# 2  https://dadosabertos.camara.leg.br/api/v2/part...      PR             57
#
#   email                                            urlFoto          dataHora  \
# ...

# %%
mandatos_externos = camara_client.get_deputado_mandatos_externos(deputado_id = 160592)
mandatos_externos_df = pd.DataFrame(mandatos_externos)
mandatos_externos_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/deputados/160592/mandatosExternos
#          cargo siglaUf          municipio anoInicio anoFim  \
# 0  Prefeito(a)      PR  Cruzeiro do Oeste      2005   2008
# 1  Prefeito(a)      PR  Cruzeiro do Oeste      2009   2010
#
#   siglaPartidoEleicao                                  uriPartidoEleicao
# 0                  PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 1                  PT  https://dadosabertos.camara.leg.br/api/v2/part...

# %%
lideres = camara_client.get_legislatura_lideres(57)
lideres_df = pd.DataFrame(lideres)
lideres_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres
# ...

# %%
mesa = camara_client.get_legislatura_mesa(57)
mesa_df = pd.DataFrame(mesa)
mesa_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/mesa
#         id                                                uri  \
# 0    73486  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1   160517  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    74317  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3   220561  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4    74270  https://dadosabertos.camara.leg.br/api/v2/depu...
# 5   204358  https://dadosabertos.camara.leg.br/api/v2/depu...
# 6   220650  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7   204426  https://dadosabertos.camara.leg.br/api/v2/depu...
# 8    74398  https://dadosabertos.camara.leg.br/api/v2/depu...
# 9   220528  https://dadosabertos.camara.leg.br/api/v2/depu...
# 10  178954  https://dadosabertos.camara.leg.br/api/v2/depu...
# 11  178933  https://dadosabertos.camara.leg.br/api/v2/depu...
# ...

# %%
proposicoes = camara_client.get_proposicoes(idDeputadoAutor = 160592)
proposicoes_df = pd.DataFrame(proposicoes)
proposicoes_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes
# ...

# %%
proposicao = camara_client.get_proposicao(proposicao_id=2544926)
proposicao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926
# {'id': 2544926,
#  'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926',
#  'siglaTipo': 'PEC',
#  'codTipo': 136,
#  'numero': 31,
#  'ano': 2025,
#  'ementa': 'Altera os arts. 5º e 10 da Emenda Constitucional nº 103, de 12 de novembro de 2019, para reduzir a idade de aposentadoria da mulher ocupante de cargo de agente penitenciário, agente socioeducativo ou de policial dos órgãos referidos.',
#  'dataApresentacao': '2025-08-13T15:20',
#  'uriOrgaoNumerador': None,
#  'statusProposicao': {'dataHora': '2025-08-13T15:20',
#   'sequencia': 2,
#   'siglaOrgao': 'MESA',
#   'uriOrgao': 'https://dadosabertos.camara.leg.br/api/v2/orgaos/4',
#   'uriUltimoRelator': None,
#   'regime': '.',
#   'descricaoTramitacao': 'Apresentação de Proposição',
#   'codTipoTramitacao': '100',
# ...

# %%
proposicao = camara_client.get_proposicao_autores(proposicao_id=2544926)
proposicao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926/autores
# [{'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220714',
#   'nome': 'Adail Filho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 101,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/136811',
#   'nome': 'Afonso Hamm',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 86,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204495',
#   'nome': 'Airton Faleiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 54,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73579',
#   'nome': 'Alberto Fraga',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 6,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220538',
# ...

# %%
proposicao = camara_client.get_proposicao_tramitacoes(proposicao_id=2544926)
proposicao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926/tramitacoes
# [{'dataHora': '2025-08-13T15:20',
#   'sequencia': 2,
#   'siglaOrgao': 'MESA',
#   'uriOrgao': 'https://dadosabertos.camara.leg.br/api/v2/orgaos/4',
#   'uriUltimoRelator': None,
#   'regime': '.',
#   'descricaoTramitacao': 'Apresentação de Proposição',
#   'codTipoTramitacao': '100',
#   'descricaoSituacao': None,
#   'codSituacao': None,
#   'despacho': 'Apresentação da PEC n. 31/2025 (Proposta de Emenda à Constituição), pelas Deputada Erika Kokay (PT/DF -Fdr PT-PCdoB-PV) e outros, que "Altera os arts. 5º e 10 da Emenda Constitucional nº 103, de 12 de novembro de 2019, para reduzir a idade de aposentadoria da mulher ocupante de cargo de agente penitenciário, agente socioeducativo ou de policial dos órgãos referidos".',
#   'url': 'https://www.camara.leg.br/proposicoesWeb/prop_mostrarintegra?codteor=2973673',
#   'ambito': 'Regimental',
# ...

# %%
proposicao = camara_client.get_proposicao_votacoes(proposicao_id=2544926)
proposicao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926/votacoes
# []

# %%
camara_client.get_proposicao_temas(proposicao_id=2544926)
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926/temas
# [{'codTema': 44, 'tema': 'Direitos Humanos e Minorias', 'relevancia': 0},
#  {'codTema': 52, 'tema': 'Previdência e Assistência Social', 'relevancia': 0}]

# %%
camara_client.get_proposicao_relacionadas(proposicao_id=2544926)
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/proposicoes/2544926/relacionadas
# []

# %%
votacoes = camara_client.get_votacoes(dataInicio = '2025-01-01', dataFim = '2025-03-31')
votacoes_df = pd.DataFrame(votacoes)
votacoes_df
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes
#              id                                                uri  \
# 0    2442848-52  https://dadosabertos.camara.leg.br/api/v2/vota...
# 1    2442848-50  https://dadosabertos.camara.leg.br/api/v2/vota...
# 2    2442848-47  https://dadosabertos.camara.leg.br/api/v2/vota...
# 3    2442848-42  https://dadosabertos.camara.leg.br/api/v2/vota...
# 4    2410601-48  https://dadosabertos.camara.leg.br/api/v2/vota...
# ...

# %%
votacao = camara_client.get_votacao(votacao_id='2442848-42')
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes/2442848-42

# %%
votacao
# Out:
# {'id': '2442848-42',
#  'uri': 'https://dadosabertos.camara.leg.br/api/v2/votacoes/2442848-42',
#  'data': '2025-03-27',
#  'dataHoraRegistro': '2025-03-27T12:28:10',
#  'siglaOrgao': 'PLEN',
#  'uriOrgao': 'https://dadosabertos.camara.leg.br/api/v2/orgaos/180',
#  'idOrgao': 180,
#  'uriEvento': 'https://dadosabertos.camara.leg.br/api/v2/eventos/75672',
#  'idEvento': 75672,
#  'descricao': 'Rejeitado o Requerimento. Sim: 43; Não: 268; Abstenção: 9; Total: 320.',
#  'aprovacao': 0,
#  'descUltimaAberturaVotacao': None,
#  'dataHoraUltimaAberturaVotacao': None,
#  'ultimaApresentacaoProposicao': {'dataHoraRegistro': None,
#   'descricao': None,
#   'uriProposicaoCitada': None},
#  'efeitosRegistrados': [],
#  'objetosPossiveis': [{'id': 2490538,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/2490538',
#    'siglaTipo': 'RPD',
#    'codTipo': 328,
#    'numero': 4,
#    'ano': 0,
#    'ementa': 'Requerimento de Retirada de Matéria da Pauta - PDL 311/2024'},
# ...

# %%
votacao = camara_client.get_votacao_orientacoes(votacao_id='2442848-42')
votacao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes/2442848-42/orientacoes
# [{'orientacaoVoto': '',
#   'codTipoLideranca': 'B',
#   'siglaPartidoBloco': 'Bl PlFdrPTUniPp...',
#   'codPartidoBloco': None,
#   'uriPartidoBloco': None},
#  {'orientacaoVoto': 'Obstrução',
#   'codTipoLideranca': 'P',
#   'siglaPartidoBloco': 'NOVO',
#   'codPartidoBloco': 37901,
#   'uriPartidoBloco': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37901'},
#  {'orientacaoVoto': 'Não',
#   'codTipoLideranca': 'B',
#   'siglaPartidoBloco': 'Maioria',
#   'codPartidoBloco': None,
#   'uriPartidoBloco': None},
#  {'orientacaoVoto': 'Não',
#   'codTipoLideranca': 'B',
#   'siglaPartidoBloco': 'Governo',
#   'codPartidoBloco': None,
#   'uriPartidoBloco': None},
#  {'orientacaoVoto': 'Obstrução',
#   'codTipoLideranca': 'B',
#   'siglaPartidoBloco': 'Minoria',
#   'codPartidoBloco': None,
#   'uriPartidoBloco': None},
#  {'orientacaoVoto': '',
# ...

# %%
votacao = camara_client.get_votacao_votos(votacao_id='2442848-42')
votacao
# Out:
# INFO:src.clients.camara_client:Fazendo requisição para: https://dadosabertos.camara.leg.br/api/v2/votacoes/2442848-42/votos
# [{'tipoVoto': 'Não',
#   'dataRegistroVoto': '2025-03-27T12:27:46',
#   'deputado_': {'id': 220695,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220695',
#    'nome': 'Rogéria Santos',
#    'siglaPartido': 'REPUBLICANOS',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
#    'siglaUf': 'BA',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/220695.jpg',
#    'email': 'dep.rogeriasantos@camara.leg.br'}},
#  {'tipoVoto': 'Não',
#   'dataRegistroVoto': '2025-03-27T12:27:29',
#   'deputado_': {'id': 160569,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/160569',
#    'nome': 'Waldenor Pereira',
#    'siglaPartido': 'PT',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844',
#    'siglaUf': 'BA',
#    'idLegislatura': 57,
# ...
